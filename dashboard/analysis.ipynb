# %%
import pandas as pd 
df = pd.read_csv(
    "../data/player_events.csv",
    parse_dates=["event_time"]
)
df.head()
# Out:
#    player_id          event_time  day         event_name  stage  gold_change  \
# 0          1 2026-08-01 00:47:00    0      hero_upgraded    NaN         -100
# 1          1 2026-08-01 01:36:00    0        hero_recuit    NaN            0
# 2          1 2026-08-01 18:42:00    0  tutorial_complete    NaN            0
# 3          1 2026-08-01 19:07:00    0    battle_complete    1.0            0
# 4          1 2026-08-01 23:09:00    0         game_start    NaN            0
#
#    purchase_value  gold_balance
# 0             0.0          -100
# 1             0.0          -100
# 2             0.0          -100
# 3             0.0          -100
# 4             0.0          -100

# %%
players = df["player_id"].nunique()

players
# Out:
# 10000

# %%
day1_players = df.loc[df["day"] == 1, "player_id"].nunique()

d1_retention = day1_players/players
print(f"D1 Retention:{d1_retention:.2%}")
# Out:
# D1 Retention:51.53%

# %%
for day in [1,3,7]:
    retention = df.loc[
        df["day"] == day,
        "player_id"].nunique()

    rate = retention/players
    print(f"D{day} Retention: {rate:.2%}")
    # print(f"D{day} Retention: {rate:.2%}")
# Out:
# D1 Retention: 51.53%
# D3 Retention: 10.16%
# D7 Retention: 0.03%

# %%
upgraded_player = set(
    df.loc[
        (df["day"] == 0)
        & (df["event_name"] =="hero_upgrade"),
        "player_id"
    ]
)

day1_players = set(
    df.loc[
        df["day"] == 1,
        "player_id"
    ]
)

# all_players = set(df["player_id"].nunique())
all_players = set(df["player_id"].unique())

# %%
# %%time

upgrade_retention = (len(upgraded_player & day1_players)/ len(upgraded_player))

non_upgrade_players = (all_players - upgraded_player )

non_upgrade_retention = (
    len(non_upgrade_players & day1_players) / len(non_upgrade_players)
)

print(
    f"Upgraded D1 retention: "
    f"{upgrade_retention:.2%}"
)

print(
    f"No upgrade D1 retention: "
    f"{non_upgrade_retention:.2%}"
)

# %%
# %%time 
1+1
